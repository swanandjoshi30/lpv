# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 1. Image preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# 2. Load dataset (IMPORTANT: set correct path)
train_data = train_datagen.flow_from_directory(
    'dataset/train',
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

test_data = test_datagen.flow_from_directory(
    'dataset/validation',
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

# 3. Build CNN model
model = Sequential()

# Convolution + Pooling
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# Flatten
model.add(Flatten())

# Fully connected layers
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

# Output layer (multi-class)
model.add(Dense(train_data.num_classes, activation='softmax'))

# 4. Compile
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 5. Train
model.fit(
    train_data,
    epochs=10,
    validation_data=test_data
)

# 6. Evaluate
loss, accuracy = model.evaluate(test_data)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 17
#      14 test_datagen = ImageDataGenerator(rescale=1./255)
#      16 # 2. Load dataset (IMPORTANT: set correct path)
# ---> 17 train_data = train_datagen.flow_from_directory(
#      18     'dataset/train',
#      19     target_size=(128, 128),
#      20     batch_size=32,
#      21     class_mode='categorical'
#      22 )
#      24 test_data = test_datagen.flow_from_directory(
#      25     'dataset/validation',
#      26     target_size=(128, 128),
#      27     batch_size=32,
#      28     class_mode='categorical'
#      29 )
#      31 # 3. Build CNN model
#
# File C:\Python312\Lib\site-packages\keras\src\legacy\preprocessing\image.py:1136, in ImageDataGenerator.flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1118 def flow_from_directory(
#    1119     self,
#    1120     directory,
#    (...)   1134     keep_aspect_ratio=False,
#    1135 ):
# -> 1136     return DirectoryIterator(
#    1137         directory,
#    1138         self,
#    1139         target_size=target_size,
#    1140         color_mode=color_mode,
#    1141         keep_aspect_ratio=keep_aspect_ratio,
#    1142         classes=classes,
#    1143         class_mode=class_mode,
#    1144         data_format=self.data_format,
#    1145         batch_size=batch_size,
#    1146         shuffle=shuffle,
#    1147         seed=seed,
#    1148         save_to_dir=save_to_dir,
#    1149         save_prefix=save_prefix,
#    1150         save_format=save_format,
#    1151         follow_links=follow_links,
#    1152         subset=subset,
#    1153         interpolation=interpolation,
#    1154         dtype=self.dtype,
#    1155     )
#
# File C:\Python312\Lib\site-packages\keras\src\legacy\preprocessing\image.py:456, in DirectoryIterator.__init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     454 if not classes:
#     455     classes = []
# --> 456     for subdir in sorted(os.listdir(directory)):
#     457         if os.path.isdir(os.path.join(directory, subdir)):
#     458             classes.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'dataset/train'
